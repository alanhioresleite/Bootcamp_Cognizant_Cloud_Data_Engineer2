# %%
##Importando as bibliotecas
import pandas as pd
import numpy as np
import datetime as dt
import pandera as pa

# %% [markdown]
# Instalando biblioteca pandera
# pip install pandera

# %%
##Extraindo os dados da fonte de dados excel(planilha)
df_cenipa = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df_cenipa.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
# 5              52243               52243               52243
# 6              50713               50713               50713
# 7              45334               45334               45334
# 8              45391               45391               45391
# 9              52244               52244               52244
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# ...

# %%
##Deletando as colunas desnecessárias
df_cenipa_atual = df_cenipa.drop(columns=['codigo_ocorrencia1', 'codigo_ocorrencia3', 'divulgacao_relatorio_numero', 'codigo_ocorrencia4', 'ocorrencia_latitude', 'ocorrencia_longitude', 'investigacao_aeronave_liberada', 'investigacao_status', 'divulgacao_relatorio_publicado', 'ocorrencia_pais', 'divulgacao_dia_publicacao', 'total_aeronaves_envolvidas', 'ocorrencia_saida_pista' ], axis=1)
df_cenipa_atual
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
##validando a base com a biblioteca pandera
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String), 
        "ocorrencia_cidade": pa.Column(pa.String), 
        "ocorrencia_uf": pa.Column(pa.String), 
        "ocorrencia_aerodromo": pa.Column(pa.String), 
        "ocorrencia_dia": pa.Column(pa.DateTime), 
        "ocorrencia_hora": pa.Column(pa.String), 
        "total_recomendacoes": pa.Column(pa.Int) 
    } 
)

# %%
##Chamando a validação(continuar)
schema.validate(df_cenipa_atual)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10404/4110882314.py in <module>
#       1 ##Chamando a validação
# ----> 2 schema.validate(df_cenipa_atual)
#
# ~\anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     517             return check_obj.pandera.add_schema(self)
#     518
# --> 519         return self._validate(
#     520             check_obj=check_obj,
#     521             head=head,
#
# ~\anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     691                 check_results.append(check_utils.is_table(result))
#     692             except errors.SchemaError as err:
# --> 693                 error_handler.collect_error("schema_component_check", err)
# ...

# %%
##df_cenipa_atual.count() ##vericando quantidade de colunas e linhas em cada coluna
df_cenipa_atual.dtypes ##verificando os types de dados
##df_cenipa_atual['ocorrencia_dia'].dt.month ##exebindo só o mês do campo data
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object
